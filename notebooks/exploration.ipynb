# %% [markdown]
# # Fraud data exploration
#
# Use this notebook to inspect raw transactions and iterate on features before training.

# %%
import pandas as pd
from pathlib import Path

raw_path = Path("../data/raw")
processed_path = Path("../data/processed")
print("raw files:", list(raw_path.glob("*")))
print("processed files:", list(processed_path.glob("*")))
